# %% [markdown]
# ## Getting Started With Langchain and open ai

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPEN_API_KEY'] = os.getenv("OPEN_API_KEY")
## Langsmith Tracking

os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 from langchain_openai import ChatOpenAI
# ----> 2 llm = ChatOpenAI(model="gpt-4o")
#       3 print(llm)
#
# File c:\Users\User\Desktop\Langchain\venv\lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\User\Desktop\Langchain\venv\lib\site-packages\langchain_openai\chat_models\base.py:1090, in BaseChatOpenAI.validate_environment(self)
#    1080         self.http_async_client = httpx.AsyncClient(
#    1081             proxy=self.openai_proxy, verify=global_ssl_context
#    1082         )
#    1083     async_specific = {
#    1084         "http_client": self.http_async_client
#    1085         or _get_default_async_httpx_client(
#    (...)
#    1088         "api_key": async_api_key_value,
#    1089     }
# -> 1090     self.root_async_client = openai.AsyncOpenAI(
#    1091         **client_params,
#    1092         **async_specific,  # type: ignore[arg-type]
#    1093     )
#    1094     self.async_client = self.root_async_client.chat.completions
#    1095 return self
#
# File c:\Users\User\Desktop\Langchain\venv\lib\site-packages\openai\_client.py:514, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     512     api_key = os.environ.get("OPENAI_API_KEY")
#     513 if api_key is None:
# --> 514     raise OpenAIError(
#     515         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     516     )
#     517 if callable(api_key):
#     518     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
## Input and get response from LM
result = llm.invoke("What is ai")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 ## Input and get response from LM
# ----> 2 llm.invoke("What is ai")
#
# NameError: name 'llm' is not defined

# %%
print(result)

# %%
### ChatPrompt Templates 
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI engineer. provide me answer based on the question"),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI engineer. provide me answer based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = prompt | llm
response = chain.invoke({"input":"Can you tell me about langchain?"})
print(response)
# Out:
# messages=[SystemMessage(content='You are an expert AI engineer. provide me answer based on the question', additional_kwargs={}, response_metadata={}), HumanMessage(content='Can you tell me about langchain?', additional_kwargs={}, response_metadata={})]

# %%
type(response)
# Out:
# langchain_core.prompt_values.ChatPromptValue

# %%
## string output Parser
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt | llm | output_parser

response = chain.invoke({"input": "Can ou tell me about Langsmith?"})
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 from langchain_core.output_parsers import StrOutputParser
#       3 output_parser = StrOutputParser()
# ----> 4 chain = prompt | llm | output_parser
#       6 response = chain.invoke({"input": "Can ou tell me about Langsmith?"})
#       7 print(response)
#
# NameError: name 'llm' is not defined
