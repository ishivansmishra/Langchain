# %% [markdown]
# ## Embedding Techniques
#
# Converting text into vectors

# %%
import os
from dotenv import load_dotenv
load_dotenv()  ## Load all the environement variables
# Out:
# True

# %%
os.environ["OPEN_API_KEY"] = os.getenv("OPEN_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model = "text-embedding-3-large")
embeddings
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 from langchain_openai import OpenAIEmbeddings
# ----> 2 embeddings = OpenAIEmbeddings(model = "text-embedding-3-large")
#       3 embeddings
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\User\Desktop\Langchain\venv\lib\site-packages\langchain_openai\embeddings\base.py:448, in OpenAIEmbeddings.validate_environment(self)
#     443         self.http_async_client = httpx.AsyncClient(proxy=self.openai_proxy)
#     444     async_specific = {
#     445         "http_client": self.http_async_client,
#     446         "api_key": async_api_key_value,
#     447     }
# --> 448     self.async_client = openai.AsyncOpenAI(
#     449         **client_params,
#     450         **async_specific,  # type: ignore[arg-type]
#     451     ).embeddings
#     452 return self
#
# File c:\Users\User\Desktop\Langchain\venv\lib\site-packages\openai\_client.py:514, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     512     api_key = os.environ.get("OPENAI_API_KEY")
#     513 if api_key is None:
# --> 514     raise OpenAIError(
#     515         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     516     )
#     517 if callable(api_key):
#     518     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
text = "This is a tutorail on OpenAI embedding"
query_result = embeddings.embed_query(text)
query_result

# %%
len(query_result)

# %%
embeddings_1024 = OpenAIEmbeddings(model="text-embedding-3-large",dimensions=1024)

# %%
text = "this is a tuturial on Openai embeddings"
query_result = embeddings_1024.embed_query(text)
len(query_result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 text = "this is a tuturial on Openai embeddings"
# ----> 2 query_result = embeddings_1024.embed_query(text)
#       3 query_result
#
# NameError: name 'embeddings_1024' is not defined
